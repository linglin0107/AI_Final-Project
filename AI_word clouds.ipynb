# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import pandas as pd
import os
import matplotlib.pyplot as plt
% matplotlib inline

# %%
os.chdir('/Documents/MSIS/Fall 2020/Team Project')
os.getcwd()
# Out:
# '/Documents/MSIS/Fall 2020/Team Project'

# %%
yelpReview2020 = pd.read_csv('YelpReview_2020.csv').astype({'date': 'datetime64[ns]'}) 
yelpReview2020.head()
#yelpCovid = pd.read_csv('YelpCovid.csv')
# Out:
#               business_id       date  \
# 0  -1m9o3vGRA8IBPNvNqKLmA 2020-11-27
# 1  -1m9o3vGRA8IBPNvNqKLmA 2020-11-14
# 2  -1m9o3vGRA8IBPNvNqKLmA 2020-10-15
# 3  -28hEE6AcAUbJctGwvC9kw 2014-12-28
# 4  -28hEE6AcAUbJctGwvC9kw 2020-11-28
#
#                                                 text
# 0  Call early for reservations during the pandemi...
# 1  easy five stars. sexy dark ambiance. beautiful...
# 2  Bavette's steakhouse is a true Gem. I loved th...
# 3  Things are looking good at the Culinary Pharma...
# 4  Yes, my review of the Culinary pharmacy on Nel...

# %%
yelpReview2020.dtypes
# Out:
# business_id            object
# date           datetime64[ns]
# text                   object
# dtype: object

# %%
yelpReview2020[yelpReview2020['date'] < '2020-01-01']
# Out:
#                  business_id       date  \
# 3     -28hEE6AcAUbJctGwvC9kw 2014-12-28
# 5     -28hEE6AcAUbJctGwvC9kw 2019-06-07
# 6     -2ym8gLGnYV5uEgyMXnL7A 2018-07-04
# 7     -2ym8gLGnYV5uEgyMXnL7A 2019-06-14
# 8     -2ym8gLGnYV5uEgyMXnL7A 2017-06-29
# ...                      ...        ...
# 4064  zqUSl5lvsdG4oLonqrMdOw 2019-07-29
# 4067  zqoPpM4GppNhRp-PkhLeSg 2018-11-12
# 4068  zqoPpM4GppNhRp-PkhLeSg 2018-07-18
# 4070  zr8Ojsm-yNhvfTzBzcKU9w 2019-06-10
# 4073  zxT_TuVfr_7OgGdZNyIwyw 2019-06-22
#
#                                                    text
# 3     Things are looking good at the Culinary Pharma...
# 5     I always get mailers about how I should use Cu...
# 6     Been coming to the Las Vegas Comicon since it'...
# 7     Lots of fun for anyone who is interested in co...
# 8     2017 Amazing Comic Con was Amazing again this ...
# ...                                                 ...
# 4064  used MY VEGAS points to get a comp show.  they...
# ...

# %%
text = yelpReview2020['text'][0]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(" ".join(yelpReview2020[yelpReview2020['date'] < '2020-01-01']['text']))

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = yelpReview2020['text'][0]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(" ".join(yelpReview2020[yelpReview2020['date'] >= '2020-01-01']['text']))

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
yelpState = pd.read_csv('yelpState.csv')  #.astype({'date': 'datetime64[ns]'}) 
yelpState.head()
# Out:
#               business_id CovidBanner TemporaryClosedUntil  IsOpen State
# 0  --1UhMGODdWsrMastO9DZw       FALSE                FALSE       1    AB
# 1  --6MefnULPED_I942VcFNA       FALSE                FALSE       1    ON
# 2  --7zmmkVg-IMGaXbuVd0SQ       FALSE                FALSE       1    NC
# 3  --8LPVSo5i0Oo61X01sV9A       FALSE                FALSE       1    AZ
# 4  --9QQLMTbFzLJ_oT-ON3Xw       FALSE                FALSE       1    AZ

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(" ".join(yelpState[yelpState['CovidBanner'] != 'FALSE']['CovidBanner'].dropna()))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
yelpState[yelpState['CovidBanner'] != 'FALSE']['CovidBanner'].dropna()
# Out:
# 22        We are back! This Sport Clips location is offi...
# 52        We are seeing patients both virtually and in p...
# 83        Hola amigos! The Cantina Location is Now open!...
# 109       Due to some recent positive COVID-19 cases, th...
# 118       All 7 Stores Are Open!\nMonday - Friday 9:00am...
#                                 ...
# 206692    F45 is working hard to provide safe solutions ...
# 206702    Most stores open 9am-9pm weekdays. Seniors-onl...
# 206703    We have been offering no human contact car rep...
# 206707    Since 1889, Carhartt existed to serve and prot...
# 206767    Our touring schedules and operating hours may ...
# Name: CovidBanner, Length: 13501, dtype: object

# %%
wordcloud = WordCloud().generate(" ".join(   \
            yelpState[yelpState['CovidBanner'] != 'FALSE'][yelpState['TemporaryClosedUntil'] == 'FALSE']['CovidBanner'].dropna()))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
wordcloud = WordCloud().generate(" ".join(   \
            yelpState[yelpState['CovidBanner'] != 'FALSE'][yelpState['TemporaryClosedUntil'] != 'FALSE']['CovidBanner'].dropna()))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
